# %%
import torch
from torch import nn
import torchvision.datasets as datasets

mnist_train = datasets.FashionMNIST(root='./root', download=True, train=True)

# import torch
# from torch import nn

# import torchvision.datasets as datasets

# mnist_train = datasets.FashionMNIST(root='./data', download=True, train=True)
# print(mnist_train[2])

# %%
print(mnist_train[0])
# Out:
# (<PIL.Image.Image image mode=L size=28x28 at 0x1194FC830>, 9)

# %%
mnist_train[5][0]
# Out:
# <PIL.Image.Image image mode=L size=28x28>

# %%
print(mnist_train[5])
# Out:
# (<PIL.Image.Image image mode=L size=28x28 at 0x119544140>, 2)

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
print("Hello marss!")
# Out:
# Hello marss!

# %%
cool = "Deep Learning with Python"

# %%
print(cool)
# Out:
# Deep Learning with Python

# %% [markdown]
# # Heading!!!
#
# Hello **world**
